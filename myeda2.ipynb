# %% [markdown]
# Ans 1,,

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_excel('flight_price.xlsx')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# Ans2

# %%
plt.figure(figsize=(20,15))
sns.histplot(data=df["Price"],kde=True)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %% [markdown]
# The above distribution is positively skewed

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
#     The above observations show tha the maximum price is 79512.0000 and the minimum price is 1759

# %%
plt.figure(figsize=(30,50))
sns.boxplot(data=df,x=df['Airline'],y=df['Price'])
# Out:
# <AxesSubplot: xlabel='Airline', ylabel='Price'>

# %% [markdown]
# Ans5....In the above boxplot we can see the outliers.

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# Ans6...... We can find the best season by date_of_journey.

# %% [markdown]
# Ans7,,,,

# %% [markdown]
# I would use Price feature and make a count plot on it.

# %% [markdown]
# Ans8,,,,

# %% [markdown]
# I would use correlation to find the realtionship between the price factor and other features.

# %% [markdown]
# Ans9....

# %%
df1=pd.read_csv('goggle_clean.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews     Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19000.0     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9      967  14000.0    500000  Free    0.0
# 2  ART_AND_DESIGN     4.7    87510      8.7   5000000  Free    0.0
# 3  ART_AND_DESIGN     4.5   215644  25000.0  50000000  Free    0.0
# 4  ART_AND_DESIGN     4.3      967      2.8    100000  Free    0.0
#
#   Content Rating                     Genres         Current Ver   Android Ver  \
# 0       Everyone               Art & Design               1.0.0  4.0.3 and up
# ...

# %% [markdown]
# Ans10

# %%
df1.shape
# Out:
# (10840, 16)

# %% [markdown]
# Ans11

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0           0
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Current Ver          8
# Android Ver          2
# Date                 0
# Month                0
# Year                 0
# dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=df1,x='Size',y='Rating')
# Out:
# <AxesSubplot: xlabel='Size', ylabel='Rating'>

# %%
df1.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews     Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19000.0     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9      967  14000.0    500000  Free    0.0
# 2  ART_AND_DESIGN     4.7    87510      8.7   5000000  Free    0.0
# 3  ART_AND_DESIGN     4.5   215644  25000.0  50000000  Free    0.0
# 4  ART_AND_DESIGN     4.3      967      2.8    100000  Free    0.0
#
#   Content Rating                     Genres         Current Ver   Android Ver  \
# 0       Everyone               Art & Design               1.0.0  4.0.3 and up
# ...

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df1,x='Price',y='Type')
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Type'>

# %%
df1.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews     Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19000.0     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9      967  14000.0    500000  Free    0.0
# 2  ART_AND_DESIGN     4.7    87510      8.7   5000000  Free    0.0
# 3  ART_AND_DESIGN     4.5   215644  25000.0  50000000  Free    0.0
# 4  ART_AND_DESIGN     4.3      967      2.8    100000  Free    0.0
#
#   Content Rating                     Genres         Current Ver   Android Ver  \
# 0       Everyone               Art & Design               1.0.0  4.0.3 and up
# ...

# %%
df_installs=df1.groupby(['App'])['Installs'].sum().sort_values(ascending=False).reset_index()

# %%
df_installs=df_installs.head(10)

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df_installs,x='Installs',y='App')
# Out:
# <AxesSubplot: xlabel='Installs', ylabel='App'>

# %% [markdown]
# Ans14..... Subway sufers is the most installed game.

# %%
df1.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews     Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19000.0     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9      967  14000.0    500000  Free    0.0
# 2  ART_AND_DESIGN     4.7    87510      8.7   5000000  Free    0.0
# 3  ART_AND_DESIGN     4.5   215644  25000.0  50000000  Free    0.0
# 4  ART_AND_DESIGN     4.3      967      2.8    100000  Free    0.0
#
#   Content Rating                     Genres         Current Ver   Android Ver  \
# 0       Everyone               Art & Design               1.0.0  4.0.3 and up
# ...

# %%
df_value=df1.Category.value_counts().sort_values(ascending=False).reset_index()

# %%
df_value=df_value.head(5)

# %%
df_value
# Out:
#       index  Category
# 0    FAMILY      1972
# 1      GAME      1144
# 2     TOOLS       843
# 3   MEDICAL       463
# 4  BUSINESS       460

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df_value,x='index',y='Category')
# Out:
# <AxesSubplot: xlabel='index', ylabel='Category'>

# %% [markdown]
# Ans16

# %%
df1.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews     Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19000.0     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9      967  14000.0    500000  Free    0.0
# 2  ART_AND_DESIGN     4.7    87510      8.7   5000000  Free    0.0
# 3  ART_AND_DESIGN     4.5   215644  25000.0  50000000  Free    0.0
# 4  ART_AND_DESIGN     4.3      967      2.8    100000  Free    0.0
#
#   Content Rating                     Genres         Current Ver   Android Ver  \
# 0       Everyone               Art & Design               1.0.0  4.0.3 and up
# ...

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df_installs,x='Installs',y='App')
# Out:
# <AxesSubplot: xlabel='Installs', ylabel='App'>

# %% [markdown]
# Ans17.....

# %%
df1.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews     Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19000.0     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9      967  14000.0    500000  Free    0.0
# 2  ART_AND_DESIGN     4.7    87510      8.7   5000000  Free    0.0
# 3  ART_AND_DESIGN     4.5   215644  25000.0  50000000  Free    0.0
# 4  ART_AND_DESIGN     4.3      967      2.8    100000  Free    0.0
#
#   Content Rating                     Genres         Current Ver   Android Ver  \
# 0       Everyone               Art & Design               1.0.0  4.0.3 and up
# ...

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=df1,x='Month',bins=12)
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Count'>
